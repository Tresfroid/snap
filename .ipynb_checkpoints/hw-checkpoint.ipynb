# %%
import snap
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt

# %%
G = snap.LoadEdgeList(snap.PNGraph, "wiki-Vote.txt", 0, 1)

print "The number of nodes:", G.GetNodes()
print "The number of nodes with self-edges:" , snap.CntSelfEdges(G)
print "The number of directed edges:", snap.CntUniqDirEdges(G)
print "The number of undirected edges:", snap.CntUniqUndirEdges(G)
print "The number of reciprocated edges:", snap.CntUniqBiDirEdges(G)
print "The number of nodes with zero out-degree:", snap.CntOutDegNodes(G, 0)
print "The number of nodes with zero in-degree:", snap.CntInDegNodes(G, 0)
print "The number of nodes with more than 10 outgoing edges:", len([n for n in G.Nodes() if n.GetOutDeg() > 10])
print "The number of nodes with fewer than 10 incoming edges:", len([n for n in G.Nodes() if n.GetInDeg() < 10])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-60ab16365da0> in <module>()
# ----> 1 G = snap.LoadEdgeList(snap.PNGraph, "wiki-Vote.txt", 0, 1)
#       2
#       3 print "The number of nodes:", G.GetNodes()
#       4 print "The number of nodes with self-edges:" , snap.CntSelfEdges(G)
#       5 print "The number of directed edges:", snap.CntUniqDirEdges(G)
#
# D:\Anaconda3\envs\py2\lib\site-packages\snap.pyc in LoadEdgeList(tspec, *args)
#  244767     if tspec == PUndirNet: return LoadEdgeList_PUndirNet(*args)
#  244768     if tspec == PDirNet: return LoadEdgeList_PDirNet(*args)
# >244769     if tspec == PNGraph : return LoadEdgeList_PNGraph(*args)
#  244770     if tspec == PNEANet : return LoadEdgeList_PNEANet(*args)
#  244771     if tspec == PNGraphMP: return LoadEdgeList_PNGraphMP(*args)
#
# D:\Anaconda3\envs\py2\lib\site-packages\snap.pyc in LoadEdgeList_PNGraph(*args)
#  233657
#  233658     """
# >233659     return _snap.LoadEdgeList_PNGraph(*args)
#  233660
#  233661 def LoadEdgeListStr_PNGraph(*args):
#
# RuntimeError: Can not open file 'wiki-Vote.txt'.

# %%
# The function to calculate the distance between two Network of the virtual tree
def distance(NId1, NId2, b, H):
    # NId1 and NId2 are the IDs of two nodes
    # b is the number of each parent's children
    # H is the height of the tree
    dist = H
    for i in range(H):
        test = H - i
        if NId1 * b / (b ** test) == NId2 * b / (b ** test):
            dist -= 1
        else:
            break
    return dist

# %%
# The function for decentralized search
# Given a graph and two node IDs
# step is the number that the source already gone through
def search(Graph, ID1, ID2, step):
    if Graph.IsEdge(ID1, ID2):
        return step + 1
    else:
        neighbors = {}
        for i in xrange(5):
            other = Graph.GetNI(ID1).GetOutNId(i)
            neighbors[other] = distance(other, ID2, 2, 10)
        S = sorted(neighbors.items(), key = lambda x: x[1])
        if S[0][1] < distance(ID1, ID2, 2, 10):
            return search(Graph, S[0][0], ID2, step + 1)
        else:
            return 0

# %%
# The basic parameters of the problem
NodeNum = 1024
EdgeNum = 0
b = 2
H = 10
IdList = range(NodeNum)
Sampling = list(np.ones(NodeNum) / float(NodeNum))

# Construct the list of alphas and the dictionary of results
alphas = [i * 0.1 for i in range(1, 101)]
paths = []
rates = []

# For different alpha, construct new graphs and do the same calculation
for alpha in alphas:
    # Generate an empty graph with 1024 nodes and no edges
    Network = snap.GenRndGnm(snap.PNGraph, NodeNum, EdgeNum, True)
    for node in Network.Nodes():
        center = node.GetId()
        chosen = []
        probs = np.array([b ** (-alpha * distance(center, other, b, H)) for other in IdList])
        probs[center] = 0
        for i in range(5):
            for some in chosen:
                probs[chosen] = 0
            probs = probs / sum(probs)
            new = np.random.choice(IdList, 1, p = list(probs))[0]
            chosen.append(new)
            Network.AddEdge(center, new)

    # Do decentralized search in the constructed network
    successes = 0
    sumpath = 0
    for k in xrange(1000):
        samples = np.random.choice(IdList, 2, replace = False, p = Sampling)
        s = samples[0]
        t = samples[1]
        searching = search(Network, s, t, 0)
        if searching != False:
            successes += 1
            sumpath += searching
    rates.append(successes / 1000.0)
    paths.append(sumpath / float(successes))
    print "alphas: " ,alpha
# Out:
# alphas:  0.1
# alphas:  0.2
# alphas:  0.3
# alphas:  0.4
# alphas:  0.5
# alphas:  0.6
# alphas:  0.7
# alphas:  0.8
# alphas:  0.9
# alphas:  1.0
# alphas:  1.1
# alphas:  1.2
# alphas:  1.3
# alphas:  1.4
# alphas:  1.5
# alphas:  1.6
# alphas:  1.7
# alphas:  1.8
# alphas:  1.9
# alphas:  2.0
# alphas:  2.1
# alphas:  2.2
# alphas:  2.3
# alphas:  2.4
# alphas:  2.5
# alphas:  2.6
# alphas:  2.7
# alphas:  2.8
# alphas:  2.9
# alphas:  3.0
# alphas:  3.1
# alphas:  3.2
# alphas:  3.3
# alphas:  3.4
# alphas:  3.5
# alphas:  3.6
# alphas:  3.7
# alphas:  3.8
# alphas:  3.9
# alphas:  4.0
# alphas:  4.1
# alphas:  4.2
# alphas:  4.3
# alphas:  4.4
# alphas:  4.5
# alphas:  4.6
# alphas:  4.7
# alphas:  4.8
# alphas:  4.9
# alphas:  5.0
# alphas:  5.1
# alphas:  5.2
# alphas:  5.3
# alphas:  5.4
# alphas:  5.5
# alphas:  5.6
# alphas:  5.7
# alphas:  5.8
# alphas:  5.9
# alphas:  6.0
# alphas:  6.1
# alphas:  6.2
# alphas:  6.3
# alphas:  6.4
# alphas:  6.5
# alphas:  6.6
# alphas:  6.7
# alphas:  6.8
# alphas:  6.9
# alphas:  7.0
# alphas:  7.1
# alphas:  7.2
# alphas:  7.3
# alphas:  7.4
# alphas:  7.5
# alphas:  7.6
# alphas:  7.7
# alphas:  7.8
# alphas:  7.9
# alphas:  8.0
# alphas:  8.1
# alphas:  8.2
# alphas:  8.3
# alphas:  8.4
# alphas:  8.5
# alphas:  8.6
# alphas:  8.7
# alphas:  8.8
# alphas:  8.9
# alphas:  9.0
# alphas:  9.1
# alphas:  9.2
# alphas:  9.3
# alphas:  9.4
# alphas:  9.5
# alphas:  9.6
# alphas:  9.7
# alphas:  9.8
# alphas:  9.9
# alphas:  10.0

# %%
plt.plot(alphas, rates)
plt.xlabel("The value of alpha")
plt.ylabel("Success Rate")
plt.title("Success Rates for Decentralized Search")
plt.savefig("rates.eps")
plt.show()
plt.close()

plt.plot(alphas, paths)
plt.xlabel("The value of alpha")
plt.ylabel("The Average Length of Path")
plt.ylim(ymin = 0)
plt.title("Average Path Length for Decentralized Search")
plt.savefig("length.eps")
plt.show()
plt.close()
